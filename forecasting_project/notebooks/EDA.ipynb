# %% [markdown]
# # Time Series Forecasting - EDA and Model Development
#
# This notebook demonstrates exploratory data analysis and model development for time series forecasting.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Data

# %%
from src.data_loader import DataLoader

loader = DataLoader('data')
# df = loader.load_csv('your_data.csv')
# df.head()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Check data shape and basic statistics
# df.describe()
# df.info()

# %%
# Visualize time series
# plt.figure(figsize=(14, 6))
# plt.plot(df.index, df['value'])
# plt.title('Time Series Data')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.show()

# %% [markdown]
# ## Preprocessing

# %%
from src.preprocessor import TimeSeriesPreprocessor

preprocessor = TimeSeriesPreprocessor()
# df_clean = preprocessor.handle_missing_values(df)
# df_clean = preprocessor.remove_outliers(df_clean, 'value')
# df_normalized, params = preprocessor.normalize(df_clean)

# %% [markdown]
# ## Feature Engineering

# %%
from src.feature_engineering import FeatureEngineering

fe = FeatureEngineering()
# df_features = fe.create_lagged_features(df, 'value', [1, 7, 30])
# df_features = fe.create_rolling_features(df_features, 'value', [7, 30])
# df_features = fe.create_temporal_features(df_features)

# %% [markdown]
# ## Model Training and Evaluation

# %%
# Split data
# train, test = preprocessor.split_train_test(df_features, test_size=0.2)

# %%
# Train ARIMA
from src.model_arima import ARIMAForecaster

# arima = ARIMAForecaster(order=(1, 1, 1))
# arima.fit(train['value'])
# arima_forecast = arima.forecast(steps=len(test))

# %%
# Train Prophet
from src.model_prophet import ProphetForecaster

# prophet = ProphetForecaster()
# prophet.fit(df[['date', 'value']].rename(columns={'date': 'ds', 'value': 'y'}))
# prophet_forecast = prophet.forecast(periods=len(test))

# %% [markdown]
# ## Results and Comparison

# %%
# Compare models
from src.model_selector import ModelSelector

# selector = ModelSelector()
# results = selector.evaluate_models(models, X_test, y_test)
# print(results)
